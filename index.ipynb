# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df.drop('Unnamed: 0', axis='columns', inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
heroes_df['name'].duplicated().any()
heroes_df.loc[heroes_df['name'].duplicated(keep=False)]
# Out:
#                name  Gender Eye color            Race Hair color  Height  \
# 22            Angel    Male      blue               -      Blond   183.0
# 23            Angel    Male         -         Vampire          -   -99.0
# 47            Atlas    Male     brown          Mutant        Red   183.0
# 48            Atlas    Male      blue   God / Eternal      Brown   198.0
# 49             Atom    Male      blue               -        Red   178.0
# 50             Atom    Male         -               -          -   -99.0
# 62          Batgirl  Female         -               -          -   -99.0
# 63          Batgirl  Female     green           Human        Red   170.0
# 68           Batman    Male      blue           Human      black   188.0
# 69           Batman    Male      blue           Human      Black   178.0
# 96     Black Canary  Female      blue           Human      Blond   165.0
# 97     Black Canary  Female      blue       Metahuman      Blond   170.0
# 115        Blizzard    Male         -               -          -   -99.0
# 116        Blizzard    Male         -               -      Brown   -99.0
# 122     Blue Beetle    Male      blue               -      Brown   -99.0
# 123     Blue Beetle    Male         -               -          -   -99.0
# 155  Captain Marvel  Female      blue      Human-Kree      Blond   180.0
# 156  Captain Marvel    Male      blue           Human      Black   193.0
# 259       Firestorm    Male     brown               -      Black   -99.0
# 260       Firestorm    Male      blue           Human     Auburn   188.0
# 289         Goliath    Male         -               -          -   -99.0
# 290         Goliath    Male         -           Human          -   -99.0
# 291         Goliath    Male         -           Human          -   -99.0
# 481           Namor    Male         -               -          -   -99.0
# 482           Namor    Male      grey       Atlantean      Black   188.0
# 496            Nova    Male     brown           Human      Brown   185.0
# 497            Nova  Female     white  Human / Cosmic        Red   163.0
# 617          Speedy    Male         -           Human          -   -99.0
# 618          Speedy  Female     green           Human      Brown   -99.0
# 622      Spider-Man    Male     hazel           Human      Brown   178.0
# 623      Spider-Man       -       red           Human      Brown   178.0
# 624      Spider-Man    Male     brown           Human      Black   157.0
# 673           Toxin    Male      blue        Symbiote      Brown   188.0
# 674           Toxin    Male     black        Symbiote      Blond   191.0
# 695      Vindicator  Female     green           Human        Red   165.0
# 696      Vindicator    Male         -               -          -   -99.0
#
#              Publisher Skin color Alignment  Weight
# 22       Marvel Comics          -      good    68.0
# 23   Dark Horse Comics          -      good   -99.0
# 47       Marvel Comics          -      good   101.0
# 48           DC Comics          -       bad   126.0
# 49           DC Comics          -      good    68.0
# 50           DC Comics          -      good   -99.0
# 62           DC Comics          -      good   -99.0
# 63           DC Comics          -      good    57.0
# 68           DC Comics          -      good    95.0
# 69           DC Comics          -      good    77.0
# 96           DC Comics          -      good    58.0
# 97           DC Comics          -      good    59.0
# 115      Marvel Comics          -       bad   -99.0
# 116      Marvel Comics          -       bad   -99.0
# 122          DC Comics          -      good   -99.0
# 123          DC Comics          -      good   -99.0
# 155      Marvel Comics          -      good    74.0
# 156          DC Comics          -      good   101.0
# 259          DC Comics          -      good   -99.0
# 260          DC Comics          -      good    91.0
# 289      Marvel Comics          -      good   -99.0
# 290      Marvel Comics          -      good   -99.0
# 291      Marvel Comics          -      good   -99.0
# 481      Marvel Comics          -      good   -99.0
# 482      Marvel Comics          -      good   125.0
# 496      Marvel Comics          -      good    86.0
# 497      Marvel Comics       gold      good    59.0
# 617          DC Comics          -      good   -99.0
# 618          DC Comics          -      good   -99.0
# 622      Marvel Comics          -      good    74.0
# 623      Marvel Comics          -      good    77.0
# 624      Marvel Comics          -      good    56.0
# 673      Marvel Comics          -      good    97.0
# 674      Marvel Comics          -      good   117.0
# 695      Marvel Comics          -      good    54.0
# 696      Marvel Comics          -      good   -99.0

# %%
# Replace None with appropriate text
"""
Publisher and Weight columns are missing a few values.
All data types besides Height and Weight are strings.
Additionally, it seems height, weight, eye color, race, hair color, and skin color columns
contain many placeholder values.
"""

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col=0)
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
#
# [5 rows x 667 columns]

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()]#.sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 46          Astro Boy    Male     brown       -      Black   -99.0       NaN
# 86       Bionic Woman  Female      blue  Cyborg      Black   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 204          Darkside       -         -       -          -   -99.0       NaN
# 244        Ethan Hunt    Male     brown   Human      Brown   168.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 348        Jack Bauer    Male         -       -          -   -99.0       NaN
# 354      Jason Bourne    Male         -   Human          -   -99.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
# 389         King Kong    Male    yellow  Animal      Black    30.5       NaN
# 393      Kool-Aid Man    Male     black       -    No Hair   -99.0       NaN
# 542             Rambo    Male     brown   Human      Black   178.0       NaN
# 658          The Cape    Male         -       -          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 46           -      good   -99.0
# 86           -      good   -99.0
# 138          -         -   -99.0
# 175          -      good   -99.0
# 204          -       bad   -99.0
# 244          -      good   -99.0
# 263          -      good   -99.0
# 286       grey       bad     NaN
# 348          -      good   -99.0
# 354          -      good   -99.0
# 381          -      good   -99.0
# 389          -      good     NaN
# 393        red      good   -99.0
# 542          -      good    83.0
# 658          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
15 rows out of 734 is a minor loss, so I think it would be best to 
drop the rows missing publisher values.
"""

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
heroes_df.dropna(subset=['Publisher'], inplace=True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Marvel                 9
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# ABC Studios            4
# IDW Publishing         4
# Shueisha               4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# Microsoft              1
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Rebellion              1
# South Park             1
# J. K. Rowling          1
# Titan Books            1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
"DC Comics" and " DC Comics", "Marvel Comics" and "Marvel"
"""

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here

heroes_df.loc[heroes_df['Publisher'] == ' DC Comics', 'Publisher'] = 'DC Comics'
heroes_df.loc[heroes_df['Publisher'] == 'Marvel', 'Publisher'] = 'Marvel Comics'

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# ABC Studios            4
# Shueisha               4
# IDW Publishing         4
# Wildstorm              3
# Sony Pictures          2
# Titan Books            1
# South Park             1
# Microsoft              1
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Rebellion              1
# J. K. Rowling          1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The shared key is the 'names' column in heroes_df and the columns of powers_df.
"""

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)

merge_temp_power = powers_df.T
merge_temp_power.loc[merge_temp_power.index.duplicated(keep=False)]
#powers_df has no duplicates
# Out:
# Empty DataFrame
# Columns: [Agility, Accelerated Healing, Lantern Power Ring, Dimensional Awareness, Cold Resistance, Durability, Stealth, Energy Absorption, Flight, Danger Sense, Underwater breathing, Marksmanship, Weapons Master, Power Augmentation, Animal Attributes, Longevity, Intelligence, Super Strength, Cryokinesis, Telepathy, Energy Armor, Energy Blasts, Duplication, Size Changing, Density Control, Stamina, Astral Travel, Audio Control, Dexterity, Omnitrix, Super Speed, Possession, Animal Oriented Powers, Weapon-based Powers, Electrokinesis, Darkforce Manipulation, Death Touch, Teleportation, Enhanced Senses, Telekinesis, Energy Beams, Magic, Hyperkinesis, Jump, Clairvoyance, Dimensional Travel, Power Sense, Shapeshifting, Peak Human Condition, Immortality, Camouflage, Element Control, Phasing, Astral Projection, Electrical Transport, Fire Control, Projection, Summoning, Enhanced Memory, Reflexes, Invulnerability, Energy Constructs, Force Fields, Self-Sustenance, Anti-Gravity, Empathy, Power Nullifier, Radiation Control, Psionic Powers, Elasticity, Substance Secretion, Elemental Transmogrification, Technopath/Cyberpath, Photographic Reflexes, Seismic Power, Animation, Precognition, Mind Control, Fire Resistance, Power Absorption, Enhanced Hearing, Nova Force, Insanity, Hypnokinesis, Animal Control, Natural Armor, Intangibility, Enhanced Sight, Molecular Manipulation, Heat Generation, Adaptation, Gliding, Power Suit, Mind Blast, Probability Manipulation, Gravity Control, Regeneration, Light Control, Echolocation, Levitation, ...]
# Index: []
#
# [0 rows x 167 columns]

# %%
#removing duplicate names from heroes_df
heroes_df.loc[heroes_df['name'].duplicated()].shape
merge_temp_hero = heroes_df.drop_duplicates(subset=['name'])

# %%
merge_temp_hero.duplicated(subset='name').any()
# Out:
# False

# %%
merge_temp_hero.set_index('name', inplace=True)
merge_temp_hero
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight
# name
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
# [700 rows x 9 columns]

# %%
hp_df1 = merge_temp_power.join(merge_temp_hero, how='inner')

# %%
hp_df2 = powers_df.T.join(heroes_df.set_index('name'), how='inner')

# %%
hp_df2
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# Abraxas            False                False               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# Abraxas                           True            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Omniscient  \
# A-Bomb                       False   False         False  ...       False
# Abe Sapien                   False   False         False  ...       False
# Abin Sur                     False   False         False  ...       False
# Abomination                  False   False         False  ...       False
# Abraxas                      False    True         False  ...       False
# ...                            ...     ...           ...  ...         ...
# Yellowjacket II              False    True         False  ...       False
# Ymir                         False   False         False  ...       False
# Yoda                         False   False          True  ...       False
# Zatanna                      False   False         False  ...       False
# Zoom                         False   False         False  ...       False
#
#                  Gender  Eye color               Race        Hair color  \
# A-Bomb             Male     yellow              Human           No Hair
# Abe Sapien         Male       blue      Icthyo Sapien           No Hair
# Abin Sur           Male       blue            Ungaran           No Hair
# Abomination        Male      green  Human / Radiation           No Hair
# Abraxas            Male       blue      Cosmic Entity             Black
# ...                 ...        ...                ...               ...
# Yellowjacket II  Female       blue              Human  Strawberry Blond
# Ymir               Male      white        Frost Giant           No Hair
# Yoda               Male      brown     Yoda's species             White
# Zatanna          Female       blue              Human             Black
# Zoom               Male        red                  -             Brown
#
#                  Height          Publisher  Skin color  Alignment  Weight
# A-Bomb            203.0      Marvel Comics           -       good   441.0
# Abe Sapien        191.0  Dark Horse Comics        blue       good    65.0
# Abin Sur          185.0          DC Comics         red       good    90.0
# Abomination       203.0      Marvel Comics           -        bad   441.0
# Abraxas           -99.0      Marvel Comics           -        bad   -99.0
# ...                 ...                ...         ...        ...     ...
# Yellowjacket II   165.0      Marvel Comics           -       good    52.0
# Ymir              304.8      Marvel Comics       white       good   -99.0
# Yoda               66.0       George Lucas       green       good    17.0
# Zatanna           170.0          DC Comics           -       good    57.0
# Zoom              185.0          DC Comics           -        bad    81.0
#
# [647 rows x 176 columns]

# %%
heroes_and_powers_df = hp_df2

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# Abraxas            False                False               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# Abraxas                           True            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Gender  \
# A-Bomb                       False   False         False  ...    Male
# Abe Sapien                   False   False         False  ...    Male
# Abin Sur                     False   False         False  ...    Male
# Abomination                  False   False         False  ...    Male
# Abraxas                      False    True         False  ...    Male
# ...                            ...     ...           ...  ...     ...
# Yellowjacket II              False    True         False  ...  Female
# Ymir                         False   False         False  ...    Male
# Yoda                         False   False          True  ...    Male
# Zatanna                      False   False         False  ...  Female
# Zoom                         False   False         False  ...    Male
#
#                  Eye color               Race        Hair color  Height  \
# A-Bomb              yellow              Human           No Hair   203.0
# Abe Sapien            blue      Icthyo Sapien           No Hair   191.0
# Abin Sur              blue            Ungaran           No Hair   185.0
# Abomination          green  Human / Radiation           No Hair   203.0
# Abraxas               blue      Cosmic Entity             Black   -99.0
# ...                    ...                ...               ...     ...
# Yellowjacket II       blue              Human  Strawberry Blond   165.0
# Ymir                 white        Frost Giant           No Hair   304.8
# Yoda                 brown     Yoda's species             White    66.0
# Zatanna               blue              Human             Black   170.0
# Zoom                   red                  -             Brown   185.0
#
#                          Publisher  Skin color  Alignment  Weight  Power Count
# A-Bomb               Marvel Comics           -       good   441.0            7
# Abe Sapien       Dark Horse Comics        blue       good    65.0           16
# Abin Sur                 DC Comics         red       good    90.0            1
# Abomination          Marvel Comics           -        bad   441.0            8
# Abraxas              Marvel Comics           -        bad   -99.0           14
# ...                            ...         ...        ...     ...          ...
# Yellowjacket II      Marvel Comics           -       good    52.0            3
# Ymir                 Marvel Comics       white       good   -99.0            6
# Yoda                  George Lucas       green       good    17.0           19
# Zatanna                  DC Comics           -       good    57.0            8
# Zoom                     DC Comics           -        bad    81.0            4
#
# [647 rows x 177 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                   Agility  Accelerated Healing  Lantern Power Ring  \
# Chameleon           False                False               False
# Crimson Crusader    False                False               False
# Luna                False                False               False
# Jim Powell          False                False               False
# Weapon XI            True                 True               False
#
#                   Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# Chameleon                         False            False       False    False
# Crimson Crusader                  False            False       False    False
# Luna                              False            False       False    False
# Jim Powell                        False            False        True    False
# Weapon XI                         False            False       False    False
#
#                   Energy Absorption  Flight  Danger Sense  ...  Gender  \
# Chameleon                     False   False         False  ...    Male
# Crimson Crusader              False    True         False  ...    Male
# Luna                          False   False         False  ...  Female
# Jim Powell                    False   False         False  ...    Male
# Weapon XI                     False   False         False  ...    Male
#
#                   Eye color   Race        Hair color  Height      Publisher  \
# Chameleon                 -      -                 -   -99.0      DC Comics
# Crimson Crusader       blue      -  Strawberry Blond   -99.0  Marvel Comics
# Luna                      -  Human                 -   -99.0  Marvel Comics
# Jim Powell                -      -                 -   -99.0    ABC Studios
# Weapon XI                 -      -                 -   -99.0  Marvel Comics
#
#                   Skin color  Alignment  Weight  Power Count
# Chameleon                  -        bad   -99.0            1
# Crimson Crusader           -       good   -99.0            4
# Luna                       -       good   -99.0            1
# Jim Powell                 -       good   -99.0            3
# Weapon XI                  -        bad   -99.0            7
#
# [5 rows x 177 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# Absorbing Man      False                False               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# Absorbing Man                    False             True        True    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Gender  \
# A-Bomb                       False   False         False  ...    Male
# Abe Sapien                   False   False         False  ...    Male
# Abin Sur                     False   False         False  ...    Male
# Abomination                  False   False         False  ...    Male
# Absorbing Man                 True   False         False  ...    Male
# ...                            ...     ...           ...  ...     ...
# Yellowjacket II              False    True         False  ...  Female
# Ymir                         False   False         False  ...    Male
# Yoda                         False   False          True  ...    Male
# Zatanna                      False   False         False  ...  Female
# Zoom                         False   False         False  ...    Male
#
#                  Eye color               Race        Hair color  Height  \
# A-Bomb              yellow              Human           No Hair   203.0
# Abe Sapien            blue      Icthyo Sapien           No Hair   191.0
# Abin Sur              blue            Ungaran           No Hair   185.0
# Abomination          green  Human / Radiation           No Hair   203.0
# Absorbing Man         blue              Human           No Hair   193.0
# ...                    ...                ...               ...     ...
# Yellowjacket II       blue              Human  Strawberry Blond   165.0
# Ymir                 white        Frost Giant           No Hair   304.8
# Yoda                 brown     Yoda's species             White    66.0
# Zatanna               blue              Human             Black   170.0
# Zoom                   red                  -             Brown   185.0
#
#                          Publisher  Skin color  Alignment  Weight  Power Count
# A-Bomb               Marvel Comics           -       good   441.0            7
# Abe Sapien       Dark Horse Comics        blue       good    65.0           16
# Abin Sur                 DC Comics         red       good    90.0            1
# Abomination          Marvel Comics           -        bad   441.0            8
# Absorbing Man        Marvel Comics           -        bad   122.0           11
# ...                            ...         ...        ...     ...          ...
# Yellowjacket II      Marvel Comics           -       good    52.0            3
# Ymir                 Marvel Comics       white       good   -99.0            6
# Yoda                  George Lucas       green       good    17.0           19
# Zatanna                  DC Comics           -       good    57.0            8
# Zoom                     DC Comics           -        bad    81.0            4
#
# [484 rows x 177 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
# Your code here (create more cells as needed)
q3_df = heroes_and_powers_df

# %%
q3_df = q3_df.groupby('Publisher').sum()
q3_df = q3_df.loc[['DC Comics', 'Marvel Comics']].T
q3_df.drop(['Power Count', 'Height', 'Weight'], inplace=True)

# %%
q3_df.reset_index(inplace=True)
q3_df.columns
# Out:
# Index(['index', 'DC Comics', 'Marvel Comics'], dtype='object', name='Publisher')

# %%
q3_df.rename(columns={'index': 'Superpower Name', 'Publisher': ''}, inplace=True)
q3_df.rename_axis(None, index=1, inplace=True)
question_3_df = q3_df

# %%
q3_df
# Out:
# Publisher        Superpower Name  DC Comics  Marvel Comics
# 0                        Agility       71.0          126.0
# 1            Accelerated Healing       51.0          100.0
# 2             Lantern Power Ring       11.0            0.0
# 3          Dimensional Awareness        7.0           16.0
# 4                Cold Resistance       15.0           25.0
# ..                           ...        ...            ...
# 162                Phoenix Force        0.0            1.0
# 163        Molecular Dissipation        1.0            0.0
# 164                Vision - Cryo        1.0            0.0
# 165                  Omnipresent        0.0            1.0
# 166                   Omniscient        0.0            1.0
#
# [167 rows x 3 columns]

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common
# Out:
# Publisher Superpower Name  Marvel Comics
# 17         Super Strength          204.0
# 5              Durability          154.0
# 25                Stamina          150.0
# 30            Super Speed          137.0
# 0                 Agility          126.0

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common
# Out:
# Publisher Superpower Name  DC Comics
# 17         Super Strength      109.0
# 25                Stamina       90.0
# 8                  Flight       86.0
# 30            Super Speed       79.0
# 5              Durability       71.0

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
The powers with the highest co-occurance are:
Intuitive aptitude            Melting                         0.7065757
Vision - X-Ray                Vision - Microscopic            0.6591248
Vision - X-Ray                Vision - Heat                   0.6591248
Vision - Heat                 Vision - Microscopic            0.6207765
Super Breath                  Vision - Microscopic            0.6097330
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %%
q4_df = powers_df
q4_df = q4_df.T
q4_df.stack()
# Out:
# 3-D Man  Agility                   True
#          Accelerated Healing      False
#          Lantern Power Ring       False
#          Dimensional Awareness    False
#          Cold Resistance          False
#                                   ...
# Zoom     Phoenix Force            False
#          Molecular Dissipation    False
#          Vision - Cryo            False
#          Omnipresent              False
#          Omniscient               False
# Length: 111389, dtype: bool

# %%
q4_df.corr()
# Out:
#                         Agility  Accelerated Healing  Lantern Power Ring  \
# Agility                1.000000             0.256731            0.024704
# Accelerated Healing    0.256731             1.000000           -0.024898
# Lantern Power Ring     0.024704            -0.024898            1.000000
# Dimensional Awareness  0.031677             0.130776           -0.025553
# Cold Resistance        0.096830             0.138495           -0.035653
# ...                         ...                  ...                 ...
# Phoenix Force          0.051351            -0.023379           -0.005018
# Molecular Dissipation -0.029240             0.064225           -0.005018
# Vision - Cryo          0.072676             0.090897           -0.007101
# Omnipresent            0.015647             0.090897           -0.007101
# Omniscient             0.015647             0.090897           -0.007101
#
#                        Dimensional Awareness  Cold Resistance  Durability  \
# Agility                             0.031677         0.096830    0.132984
# Accelerated Healing                 0.130776         0.138495    0.239692
# Lantern Power Ring                 -0.025553        -0.035653   -0.005766
# Dimensional Awareness               1.000000        -0.054332   -0.042700
# Cold Resistance                    -0.054332         1.000000    0.263499
# ...                                      ...              ...         ...
# Phoenix Force                      -0.007647        -0.010669   -0.030679
# Molecular Dissipation              -0.007647        -0.010669    0.048943
# Vision - Cryo                      -0.010822        -0.015099    0.069268
# Omnipresent                         0.277908        -0.015099    0.012924
# Omniscient                          0.277908        -0.015099    0.012924
#
#                         Stealth  Energy Absorption    Flight  Danger Sense  \
# Agility                0.392603           0.039646 -0.019537      0.227412
# Accelerated Healing    0.098497           0.153284  0.134115      0.228862
# Lantern Power Ring    -0.062493          -0.046780  0.139143     -0.028102
# Dimensional Awareness  0.045924           0.126320  0.136529      0.033346
# Cold Resistance        0.061680           0.047190 -0.049550     -0.003221
# ...                         ...                ...       ...           ...
# Phoenix Force         -0.018700           0.107261 -0.026450     -0.008409
# Molecular Dissipation -0.018700           0.107261  0.056768     -0.008409
# Vision - Cryo         -0.026466           0.151805  0.080342     -0.011901
# Omnipresent           -0.026466           0.151805  0.021454      0.120402
# Omniscient            -0.026466           0.151805  0.021454      0.120402
#
#                        ...  Web Creation  Reality Warping  Odin Force  \
# Agility                ...      0.107033         0.065107    0.072676
# Accelerated Healing    ...      0.195400         0.149085    0.090897
# Lantern Power Ring     ...     -0.018961        -0.020301   -0.007101
# Dimensional Awareness  ...      0.026170         0.536517   -0.010822
# Cold Resistance        ...     -0.040314        -0.004879   -0.015099
# ...                    ...           ...              ...         ...
# Phoenix Force          ...     -0.005674        -0.006075   -0.002125
# Molecular Dissipation  ...     -0.005674        -0.006075   -0.002125
# Vision - Cryo          ...     -0.008030        -0.008598   -0.003008
# Omnipresent            ...     -0.008030         0.349812   -0.003008
# Omniscient             ...     -0.008030         0.349812   -0.003008
#
#                        Symbiote Costume  Speed Force  Phoenix Force  \
# Agility                        0.100934     0.051351       0.051351
# Accelerated Healing            0.164466     0.064225      -0.023379
# Lantern Power Ring            -0.015144    -0.005018      -0.005018
# Dimensional Awareness          0.045337    -0.007647      -0.007647
# Cold Resistance                0.018574    -0.010669      -0.010669
# ...                                 ...          ...            ...
# Phoenix Force                 -0.004532    -0.001502       1.000000
# Molecular Dissipation         -0.004532    -0.001502      -0.001502
# Vision - Cryo                 -0.006414    -0.002125      -0.002125
# Omnipresent                   -0.006414    -0.002125      -0.002125
# Omniscient                    -0.006414    -0.002125      -0.002125
#
#                        Molecular Dissipation  Vision - Cryo  Omnipresent  \
# Agility                            -0.029240       0.072676     0.015647
# Accelerated Healing                 0.064225       0.090897     0.090897
# Lantern Power Ring                 -0.005018      -0.007101    -0.007101
# Dimensional Awareness              -0.007647      -0.010822     0.277908
# Cold Resistance                    -0.010669      -0.015099    -0.015099
# ...                                      ...            ...          ...
# Phoenix Force                      -0.001502      -0.002125    -0.002125
# Molecular Dissipation               1.000000      -0.002125    -0.002125
# Vision - Cryo                      -0.002125       1.000000    -0.003008
# Omnipresent                        -0.002125      -0.003008     1.000000
# Omniscient                         -0.002125      -0.003008     1.000000
#
#                        Omniscient
# Agility                  0.015647
# Accelerated Healing      0.090897
# Lantern Power Ring      -0.007101
# Dimensional Awareness    0.277908
# Cold Resistance         -0.015099
# ...                           ...
# Phoenix Force           -0.002125
# Molecular Dissipation   -0.002125
# Vision - Cryo           -0.003008
# Omnipresent              1.000000
# Omniscient               1.000000
#
# [167 rows x 167 columns]

# %%
corr_temp = q4_df.corr().unstack()
corr_temp = corr_temp.sort_values(kind='quicksort')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(corr_temp)
# Out:
# Flight                        Weapons Master                 -1.624340e-01
# Weapons Master                Flight                         -1.624340e-01
# Peak Human Condition          Super Strength                 -1.479212e-01
# Super Strength                Peak Human Condition           -1.479212e-01
#                               Weapons Master                 -1.376961e-01
# Weapons Master                Super Strength                 -1.376961e-01
# Flight                        Peak Human Condition           -1.325981e-01
# Peak Human Condition          Flight                         -1.325981e-01
# Stealth                       Flight                         -1.320044e-01
# Flight                        Stealth                        -1.320044e-01
# Super Speed                   Peak Human Condition           -1.226280e-01
# Peak Human Condition          Super Speed                    -1.226280e-01
# Weapons Master                Energy Absorption              -1.046224e-01
# Energy Absorption             Weapons Master                 -1.046224e-01
# Natural Weapons               Force Fields                   -1.028547e-01
# Force Fields                  Natural Weapons                -1.028547e-01
# Natural Armor                 Intelligence                   -1.018674e-01
# Intelligence                  Natural Armor                  -1.018674e-01
# Invulnerability               Peak Human Condition           -1.000927e-01
# Peak Human Condition          Invulnerability                -1.000927e-01
# Size Changing                 Weapons Master                 -9.964624e-02
# Weapons Master                Size Changing                  -9.964624e-02
# Accelerated Healing           Peak Human Condition           -9.822367e-02
# Peak Human Condition          Accelerated Healing            -9.822367e-02
# Levitation                    Durability                     -9.578625e-02
# Durability                    Levitation                     -9.578625e-02
# Probability Manipulation      Durability                     -9.259402e-02
# Durability                    Probability Manipulation       -9.259402e-02
# Weapon-based Powers           Telepathy                      -9.258201e-02
# Telepathy                     Weapon-based Powers            -9.258201e-02
# Energy Absorption             Animal Oriented Powers         -9.124637e-02
# Animal Oriented Powers        Energy Absorption              -9.124637e-02
# Energy Absorption             Stealth                        -9.044231e-02
# Stealth                       Energy Absorption              -9.044231e-02
# Energy Blasts                 Stealth                        -9.026863e-02
# Stealth                       Energy Blasts                  -9.026863e-02
# Teleportation                 Natural Weapons                -9.020612e-02
# Natural Weapons               Teleportation                  -9.020612e-02
# Intelligence                  Substance Secretion            -9.010262e-02
# Substance Secretion           Intelligence                   -9.010262e-02
# Energy Manipulation           Natural Weapons                -8.973657e-02
# Natural Weapons               Energy Manipulation            -8.973657e-02
# Energy Manipulation           Weapon-based Powers            -8.973657e-02
# Weapon-based Powers           Energy Manipulation            -8.973657e-02
# Gravity Control               Reflexes                       -8.951739e-02
# Reflexes                      Gravity Control                -8.951739e-02
# Wallcrawling                  Invulnerability                -8.897000e-02
# Invulnerability               Wallcrawling                   -8.897000e-02
# Animal Oriented Powers        Energy Blasts                  -8.859224e-02
# Energy Blasts                 Animal Oriented Powers         -8.859224e-02
# Marksmanship                  Super Strength                 -8.821443e-02
# Super Strength                Marksmanship                   -8.821443e-02
# Cold Resistance               Telekinesis                    -8.735378e-02
# Telekinesis                   Cold Resistance                -8.735378e-02
# Electrokinesis                Reflexes                       -8.596030e-02
# Reflexes                      Electrokinesis                 -8.596030e-02
# Animal Oriented Powers        Immortality                    -8.579662e-02
# Immortality                   Animal Oriented Powers         -8.579662e-02
# Jump                          Molecular Manipulation         -8.518107e-02
# Molecular Manipulation        Jump                           -8.518107e-02
# Weapon-based Powers           Cold Resistance                -8.496859e-02
# Cold Resistance               Weapon-based Powers            -8.496859e-02
# Natural Weapons               Flight                         -8.495674e-02
# Flight                        Natural Weapons                -8.495674e-02
# Invulnerability               Animal Oriented Powers         -8.328905e-02
# Animal Oriented Powers        Invulnerability                -8.328905e-02
# Telekinesis                   Heat Resistance                -8.328572e-02
# Heat Resistance               Telekinesis                    -8.328572e-02
# Cold Resistance               Intangibility                  -4.840787e-02
# Intangibility                 Cold Resistance                -4.840787e-02
# Electrokinesis                Super Strength                 -4.840726e-02
# Super Strength                Electrokinesis                 -4.840726e-02
# Weapon-based Powers           Gravity Control                -4.838100e-02
# Gravity Control               Weapon-based Powers            -4.838100e-02
# Natural Weapons               Gravity Control                -4.838100e-02
# Gravity Control               Natural Weapons                -4.838100e-02
# Reality Warping               Natural Weapons                -4.838100e-02
# Natural Weapons               Reality Warping                -4.838100e-02
# Weapon-based Powers           Reality Warping                -4.838100e-02
# Reality Warping               Weapon-based Powers            -4.838100e-02
# Natural Weapons               Duplication                    -4.838100e-02
# Duplication                   Natural Weapons                -4.838100e-02
# Psionic Powers                Cryokinesis                    -4.821621e-02
# Cryokinesis                   Psionic Powers                 -4.821621e-02
# Omnipotent                    Marksmanship                   -4.799105e-02
# Marksmanship                  Omnipotent                     -4.799105e-02
# Radiation Absorption          Marksmanship                   -4.799105e-02
# Marksmanship                  Radiation Absorption           -4.799105e-02
# Radiation Control             Marksmanship                   -4.799105e-02
# Marksmanship                  Radiation Control              -4.799105e-02
# Stamina                       Projection                     -4.795205e-02
# Projection                    Stamina                        -4.795205e-02
# Stamina                       Illumination                   -4.795205e-02
# Illumination                  Stamina                        -4.795205e-02
# Omniscient                    Stamina                        -4.795205e-02
# Stamina                       Omnipresent                    -4.795205e-02
# ...
# Omnipresent                   Omnipotent                      5.325092e-01
# Omnipotent                    Omnipresent                     5.325092e-01
#                               Omniscient                      5.325092e-01
# Omniscient                    Omnipotent                      5.325092e-01
# Reality Warping               Dimensional Awareness           5.365173e-01
# Dimensional Awareness         Reality Warping                 5.365173e-01
# Weapons Master                Marksmanship                    5.404818e-01
# Marksmanship                  Weapons Master                  5.404818e-01
# Super Strength                Durability                      5.457016e-01
# Durability                    Super Strength                  5.457016e-01
# Time Manipulation             Reality Warping                 5.469607e-01
# Reality Warping               Time Manipulation               5.469607e-01
# Vision - X-Ray                Super Breath                    5.496894e-01
# Super Breath                  Vision - X-Ray                  5.496894e-01
# Omnipotent                    Reality Warping                 5.607614e-01
# Reality Warping               Omnipotent                      5.607614e-01
# Radiation Absorption          Radiation Control               5.668831e-01
# Radiation Control             Radiation Absorption            5.668831e-01
# Vision - Microscopic          Vision - Telescopic             5.789052e-01
# Vision - Telescopic           Vision - Microscopic            5.789052e-01
# Animal Attributes             Animal Oriented Powers          5.818100e-01
# Animal Oriented Powers        Animal Attributes               5.818100e-01
# Astral Projection             Illusions                       5.819477e-01
# Illusions                     Astral Projection               5.819477e-01
# Web Creation                  Wallcrawling                    5.842343e-01
# Wallcrawling                  Web Creation                    5.842343e-01
# Cold Resistance               Heat Resistance                 5.956256e-01
# Heat Resistance               Cold Resistance                 5.956256e-01
# Time Manipulation             Time Travel                     6.084881e-01
# Time Travel                   Time Manipulation               6.084881e-01
# Super Breath                  Vision - Heat                   6.097330e-01
# Vision - Heat                 Super Breath                    6.097330e-01
# Super Breath                  Vision - Microscopic            6.097330e-01
# Vision - Microscopic          Super Breath                    6.097330e-01
# Vision - Heat                 Vision - Microscopic            6.207765e-01
# Vision - Microscopic          Vision - Heat                   6.207765e-01
# Vision - X-Ray                Vision - Heat                   6.591248e-01
# Vision - Heat                 Vision - X-Ray                  6.591248e-01
# Vision - X-Ray                Vision - Microscopic            6.591248e-01
# Vision - Microscopic          Vision - X-Ray                  6.591248e-01
# Melting                       Intuitive aptitude              7.065757e-01
# Intuitive aptitude            Melting                         7.065757e-01
# Omnipresent                   Omniscient                      1.000000e+00
# Agility                       Agility                         1.000000e+00
# Hypnokinesis                  Hypnokinesis                    1.000000e+00
# Vision - Cryo                 Vision - Cryo                   1.000000e+00
# Enhanced Memory               Enhanced Memory                 1.000000e+00
# Summoning                     Summoning                       1.000000e+00
# Projection                    Projection                      1.000000e+00
# Fire Control                  Fire Control                    1.000000e+00
# Electrical Transport          Electrical Transport            1.000000e+00
# Astral Projection             Astral Projection               1.000000e+00
# Phasing                       Phasing                         1.000000e+00
# Element Control               Element Control                 1.000000e+00
# Camouflage                    Camouflage                      1.000000e+00
# Immortality                   Immortality                     1.000000e+00
# Peak Human Condition          Peak Human Condition            1.000000e+00
# Shapeshifting                 Shapeshifting                   1.000000e+00
# Power Sense                   Power Sense                     1.000000e+00
# Dimensional Travel            Dimensional Travel              1.000000e+00
# Clairvoyance                  Clairvoyance                    1.000000e+00
# Jump                          Jump                            1.000000e+00
# Hyperkinesis                  Spatial Awareness               1.000000e+00
# Reflexes                      Reflexes                        1.000000e+00
# Hyperkinesis                  Hyperkinesis                    1.000000e+00
# Invulnerability               Invulnerability                 1.000000e+00
# Force Fields                  Force Fields                    1.000000e+00
# Power Absorption              Power Absorption                1.000000e+00
# Fire Resistance               Fire Resistance                 1.000000e+00
# Mind Control                  Mind Control                    1.000000e+00
# Precognition                  Precognition                    1.000000e+00
# Animation                     Animation                       1.000000e+00
# Seismic Power                 Seismic Power                   1.000000e+00
# Photographic Reflexes         Photographic Reflexes           1.000000e+00
# Technopath/Cyberpath          Technopath/Cyberpath            1.000000e+00
# Elemental Transmogrification  Elemental Transmogrification    1.000000e+00
# Substance Secretion           Substance Secretion             1.000000e+00
# Elasticity                    Elasticity                      1.000000e+00
# Psionic Powers                Psionic Powers                  1.000000e+00
# Radiation Control             Radiation Control               1.000000e+00
# Power Nullifier               Power Nullifier                 1.000000e+00
# Empathy                       Empathy                         1.000000e+00
# Anti-Gravity                  Anti-Gravity                    1.000000e+00
# Self-Sustenance               Self-Sustenance                 1.000000e+00
# Energy Constructs             Energy Constructs               1.000000e+00
# Enhanced Hearing              Enhanced Hearing                1.000000e+00
# Magic                         Magic                           1.000000e+00
# Telekinesis                   Telekinesis                     1.000000e+00
# Super Strength                Super Strength                  1.000000e+00
# Intelligence                  Intelligence                    1.000000e+00
# Longevity                     Longevity                       1.000000e+00
# Animal Attributes             Animal Attributes               1.000000e+00
# Power Augmentation            Power Augmentation              1.000000e+00
# Weapons Master                Weapons Master                  1.000000e+00
# Marksmanship                  Marksmanship                    1.000000e+00
# Underwater breathing          Underwater breathing            1.000000e+00
# Danger Sense                  Danger Sense                    1.000000e+00
# Flight                        Flight                          1.000000e+00
# Energy Absorption             Energy Absorption               1.000000e+00
# Stealth                       Stealth                         1.000000e+00
# Durability                    Durability                      1.000000e+00
# Cold Resistance               Cold Resistance                 1.000000e+00
# Dimensional Awareness         Dimensional Awareness           1.000000e+00
# Lantern Power Ring            Lantern Power Ring              1.000000e+00
# Accelerated Healing           Accelerated Healing             1.000000e+00
# Cryokinesis                   Cryokinesis                     1.000000e+00
# Energy Beams                  Energy Beams                    1.000000e+00
# Telepathy                     Telepathy                       1.000000e+00
# Energy Blasts                 Energy Blasts                   1.000000e+00
# Enhanced Senses               Enhanced Senses                 1.000000e+00
# Teleportation                 Teleportation                   1.000000e+00
# Death Touch                   Death Touch                     1.000000e+00
# Darkforce Manipulation        Darkforce Manipulation          1.000000e+00
# Electrokinesis                Electrokinesis                  1.000000e+00
# Weapon-based Powers           Weapon-based Powers             1.000000e+00
# Animal Oriented Powers        Animal Oriented Powers          1.000000e+00
# Possession                    Possession                      1.000000e+00
# Super Speed                   Super Speed                     1.000000e+00
# Omnitrix                      Omnitrix                        1.000000e+00
# Dexterity                     Dexterity                       1.000000e+00
# Audio Control                 Audio Control                   1.000000e+00
# Astral Travel                 Astral Travel                   1.000000e+00
# Stamina                       Stamina                         1.000000e+00
# Density Control               Density Control                 1.000000e+00
# Size Changing                 Size Changing                   1.000000e+00
# Duplication                   Duplication                     1.000000e+00
# Energy Armor                  Energy Armor                    1.000000e+00
# Nova Force                    Nova Force                      1.000000e+00
# Insanity                      Insanity                        1.000000e+00
# Omniscient                    Omnipresent                     1.000000e+00
# Wallcrawling                  Wallcrawling                    1.000000e+00
# Super Breath                  Super Breath                    1.000000e+00
# Wind Control                  Wind Control                    1.000000e+00
# Melting                       Melting                         1.000000e+00
# Vision - Microscopic          Vision - Microscopic            1.000000e+00
# Intuitive aptitude            Intuitive aptitude              1.000000e+00
# Radiation Absorption          Radiation Absorption            1.000000e+00
# Sub-Mariner                   Sub-Mariner                     1.000000e+00
# Invisibility                  Invisibility                    1.000000e+00
# Magic Resistance              Magic Resistance                1.000000e+00
# Enhanced Touch                Enhanced Touch                  1.000000e+00
# Time Manipulation             Time Manipulation               1.000000e+00
# Sonic Scream                  Sonic Scream                    1.000000e+00
# Sonar                         Sonar                           1.000000e+00
# Plant Control                 Plant Control                   1.000000e+00
# Mind Control Resistance       Mind Control Resistance         1.000000e+00
# Magnetism                     Magnetism                       1.000000e+00
# Vision - Night                Vision - Night                  1.000000e+00
# Portal Creation               Portal Creation                 1.000000e+00
# Vision - Infrared             Vision - Infrared               1.000000e+00
# Matter Absorption             Matter Absorption               1.000000e+00
# Molecular Dissipation         Molecular Dissipation           1.000000e+00
# Phoenix Force                 Phoenix Force                   1.000000e+00
# Speed Force                   Speed Force                     1.000000e+00
# Symbiote Costume              Symbiote Costume                1.000000e+00
# Odin Force                    Odin Force                      1.000000e+00
# Reality Warping               Reality Warping                 1.000000e+00
# Web Creation                  Web Creation                    1.000000e+00
# Vision - Thermal              Vision - Thermal                1.000000e+00
# Vision - X-Ray                Vision - X-Ray                  1.000000e+00
# Weather Control               Weather Control                 1.000000e+00
# Qwardian Power Ring           Qwardian Power Ring             1.000000e+00
# Radar Sense                   Radar Sense                     1.000000e+00
# Vitakinesis                   Vitakinesis                     1.000000e+00
# Vision - Heat                 Vision - Heat                   1.000000e+00
# Terrakinesis                  Terrakinesis                    1.000000e+00
# Resurrection                  Resurrection                    1.000000e+00
# The Force                     The Force                       1.000000e+00
# Grim Reaping                  Grim Reaping                    1.000000e+00
# Omnilingualism                Omnilingualism                  1.000000e+00
# Molecular Combustion          Molecular Combustion            1.000000e+00
# Telepathy Resistance          Telepathy Resistance            1.000000e+00
# Toxin and Disease Control     Toxin and Disease Control       1.000000e+00
# Levitation                    Levitation                      1.000000e+00
# Echolocation                  Echolocation                    1.000000e+00
# Light Control                 Light Control                   1.000000e+00
# Regeneration                  Regeneration                    1.000000e+00
# Gravity Control               Gravity Control                 1.000000e+00
# Probability Manipulation      Probability Manipulation        1.000000e+00
# Mind Blast                    Mind Blast                      1.000000e+00
# Power Suit                    Power Suit                      1.000000e+00
# Gliding                       Gliding                         1.000000e+00
# Adaptation                    Adaptation                      1.000000e+00
# Heat Generation               Heat Generation                 1.000000e+00
# Molecular Manipulation        Molecular Manipulation          1.000000e+00
# Enhanced Sight                Enhanced Sight                  1.000000e+00
# Intangibility                 Intangibility                   1.000000e+00
# Natural Armor                 Natural Armor                   1.000000e+00
# Animal Control                Animal Control                  1.000000e+00
# Banish                        Banish                          1.000000e+00
# Energy Manipulation           Energy Manipulation             1.000000e+00
# Heat Resistance               Heat Resistance                 1.000000e+00
# Natural Weapons               Natural Weapons                 1.000000e+00
# Energy Resistance             Energy Resistance               1.000000e+00
# Spatial Awareness             Spatial Awareness               1.000000e+00
#                               Hyperkinesis                    1.000000e+00
# Toxin and Disease Resistance  Toxin and Disease Resistance    1.000000e+00
# Vision - Telescopic           Vision - Telescopic             1.000000e+00
# Radiation Immunity            Radiation Immunity              1.000000e+00
# Water Control                 Water Control                   1.000000e+00
# Biokinesis                    Biokinesis                      1.000000e+00
# Omnipresent                   Omnipresent                     1.000000e+00
# Power Cosmic                  Power Cosmic                    1.000000e+00
# Cloaking                      Cloaking                        1.000000e+00
# Omnipotent                    Omnipotent                      1.000000e+00
# Illumination                  Illumination                    1.000000e+00
# Hair Manipulation             Hair Manipulation               1.000000e+00
# Thirstokinesis                Thirstokinesis                  1.000000e+00
# Illusions                     Illusions                       1.000000e+00
# Enhanced Smell                Enhanced Smell                  1.000000e+00
# Time Travel                   Time Travel                     1.000000e+00
# Changing Armor                Changing Armor                  1.000000e+00
# Omniscient                    Omniscient                      1.000000e+00
# dtype: float64

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
